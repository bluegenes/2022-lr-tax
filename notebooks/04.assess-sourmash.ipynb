# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

from collections import defaultdict, namedtuple

# %% [markdown]
# ## Handle Taxon Synonymy

# %%
# Some taxa need modified search terms. This dict should work for all datasets.
taxa_searchterms = {'Limosilactobacillus fermentum':'Lactobacillus fermentum|Limosilactobacillus fermentum',
                       "Veillonella rogosae": "Veillonella",
                      "Prevotella corporis": "Prevotella",
                      'Bacillus subtilis': 'Bacillus subtilis|Bacillus spizizenii',
                      'Luteovulum sphaeroides':'Rhodobacter sphaeroides|Luteovulum sphaeroides|Cereibacter sphaeroides',
                      'Phocaeicola vulgatus': 'Bacteroides vulgatus|Phocaeicola vulgatus',
                      'Luteovulum':'Rhodobacter|Luteovulum|Cereibacter',
                      'Phocaeicola':'Bacteroides|Phocaeicola',
                      'Limosilactobacillus': 'Lactobacillus|Limosilactobacillus'
                       }

# %% [markdown]
# ## Name datasets and load Theoretical Distributions

# %%
all_datasets = {"ATCC_MSA1003": ["HiFi_ATCC_MSA1003_full", "HiFi_ATCC_MSA1003_short", "Illumina_ATCC_MSA1003"],
              "Zymo_D6300": ["Illumina_Zymo_D6300","ONT_Q20_Zymo_D6300_full","ONT_Q20_Zymo_D6300_short","ONT_R10_Zymo_D6300"],
              "HiFi_Zymo_D6331": ["HiFi_Zymo_D6331"]
}
tools= ["Bracken", "BugSeq-V2", "Centrifuge-h22", 
        "Centrifuge-h500", "Kraken2", "MEGAN-LR-Nuc-HiFi", 
        "MEGAN-LR-Nuc-ONT", "MEGAN-LR-Prot", "MMseqs2", 
        "Metamaps", "Metaphlan3", "mOTUs"]

comparable_lr_tools = ["MEGAN-LR-Nuc-HiFi", "MEGAN-LR-Nuc-ONT", "MEGAN-LR-Prot", "BugSeq-V2", "MMseqs2"]# ,#"Metamaps","Centrifuge-h500"]

# %%
# filenames for all theoretical distributions
species_filenames = {"Zymo_D6300": "Zymo_D6300.theoretical-distrib.species.csv",
                     "HiFi_Zymo_D6331": "HiFi_Zymo_D6331.theoretical-distrib.species.csv",
                     "ATCC_MSA1003": "ATCC_MSA1003.theoretical-distrib.species.csv"}

genus_filenames = {"Zymo_D6300": "Zymo_D6300.theoretical-distrib.genus.csv",
                     "HiFi_Zymo_D6331": "HiFi_Zymo_D6331.theoretical-distrib.genus.csv",
                     "ATCC_MSA1003": "ATCC_MSA1003.theoretical-distrib.genus.csv"}

theoretical_distributions_dict = {"species": species_filenames, "genus": genus_filenames}

# %% [markdown]
# ## Make dict of all kreport files

# %%
# filenames for all sourmash kreports

df_thresh_folder = "sourmash-kreports-2022-10-03.genbank"
zero_thresh_folder = "../output.lr-gather/gather"

kreport_dict = defaultdict(dict)

for kreport_folder in [df_thresh_folder]:#, zero_thresh_folder]:
    for ksize in [31,51]:
        for ds, ds_list in all_datasets.items():
            for d in ds_list:
                fname = f"Sourmash-k{ksize}"
                kreportF = f"{kreport_folder}/{d}.dna-k{ksize}-sc1000.gather.genbank.kreport.txt"
                kreport_dict[d].update({fname: kreportF})
for kreport_folder in [zero_thresh_folder]:
    for ksize in [31,51]:
        for ds, ds_list in all_datasets.items():
            for d in ds_list:
                fname = f"Sourmash-k{ksize}_zeroThresh"
                kreportF = f"{kreport_folder}/{d}.dna-k{ksize}-sc1000.gather.genbank.kreport.txt"
                kreport_dict[d].update({fname: kreportF})

# %%
# now add non-sourmash kreports
import glob, os
full_kreport_files = glob.glob("All-kreports/*/inputs/*.kreport.txt")
print(len(full_kreport_files))
for f in full_kreport_files:
    if "D6331" in f:
        #mc = "HiFi_Zymo_D6331"
        rd = "HiFi_Zymo_D6331"
    elif "ATCC" in f:
        #mc = "ATCC_MSA1003"
        if "Illumina" in f:
            rd = "Illumina_ATCC_MSA1003"
        else:
            rd = "HiFi_ATCC_MSA1003_full"
    else:
        
       # mc = "Zymo_D6300"
        if "R10" in f:
            rd = "ONT_R10_Zymo_D6300"
        elif "Illumina" in f:
            rd = "Illumina_Zymo_D6300"
        else:
            rd = 'ONT_Q20_Zymo_D6300_full'
    tool = os.path.basename(f).split('.')[0]
    if "Sourmash" in tool: # no need to add these twice
        continue
    kreport_dict[rd].update({tool:f})
# ADD kreports for SIMULATED SHORT  READS 
sim_kreport_files = glob.glob("All-kreports/simread-kreports/*.kreport.txt")
print(len(sim_kreport_files))
for f in sim_kreport_files:
    if "ATCC" in f:
        rd = "HiFi_ATCC_MSA1003_short"
    elif "D6300" in f:
        rd = 'ONT_Q20_Zymo_D6300_short'
    tool = os.path.basename(f).split('.')[0]
    if "Sourmash" in tool: # no need to add these twice
        continue
    kreport_dict[rd].update({tool:f})
# Out:
# 72
# 14

# %% [markdown]
# ## Parse kreports for each dataset

# %%
TaxResult = namedtuple('TaxResult', "taxon,rank,mock_community,read_dataset,tool,d1perc,dp1perc,dp01perc,dany,cumulative_count")

# %%
def assess_read_dataset(dataset_name, read_dataset, theoretical_dict, kreport_dict, namediff_dict):
    taxresults = []
    #sp_count_dict, gn_count_dict = defaultdict(list), defaultdict(list)
    #species_fp_counts, genus_fp_counts = {}, {}
    #fp_counts= {"species": {}, "genus": {}}
    all_toolnames = kreport_dict.keys()
    
    # get theoretical distribution info
    theoretical_species = pd.read_csv(theoretical_dict["species"][dataset_name])
    theoretical_genera = pd.read_csv(theoretical_dict["genus"][dataset_name])
    
    #theoretical_sp = theoretical_species['Taxon'].tolist()
    #theoretical_gn = theoretical_genera['Taxon'].tolist()
    theoretical = {"species": theoretical_species, "genus": theoretical_genera}

    # set minimum detection threshold for this read dataset
    #detect_dict = {'0.001-perc': int(0.00001*total_reads),
    #           '0.1-perc': int(0.001*total_reads),
    #           '1-perc': int(0.01*total_reads)}

    # change this to generate results for other filtering threshold
   # dlevel = '0.001-perc'

    #for k, v in detect_dict.items():
    #    print(k, '=', v)
    detection_thresholds = [0.01, 0.001, 0.0001, 0]
    rank_labels = {"species": 'S', "genus": 'G'}
    for kreport_fname, kreportF in kreport_dict.items():    
        # read kreport
        kreport_df = pd.read_csv(kreportF, sep = '\t', header=None,
                         names = ['proportion', 'cumulative_count', 'level_count', 'rank', 'taxid', 'name'])    
        # First, search for True Positives and False Negatives
        for rank in ["species", "genus"]:
            theoretical_info = theoretical[rank]
            theoretical_taxa = theoretical_info['Taxon'].tolist()
            searchnames = []
            rk = rank_labels[rank]
            for t in theoretical_taxa:
                # for threshold reads /percent, grab total expected reads/percent
                reads_column = f"{read_dataset}_theoretical_reads"
                theoretical_reads = theoretical_info[theoretical_info['Taxon'] == t][reads_column].values[0]
                searchname = namediff_dict.get(t, t)
                searchnames.append(searchname)
                if "|" in searchname:
                    tempD = kreport_df[(kreport_df['name'].str.contains(searchname, regex=True))]
                else:
                    tempD = kreport_df[(kreport_df['name'].str.contains(t))]
                # add the cumulative count for the taxon
                # for species, this will have the effect of including all strains below, which are correct
                this_count = tempD.loc[kreport_df['rank'] == rk, 'cumulative_count'].sum()
               
                detection_info = []
                # for sourmash, check if % exceeds minimum % detection threshold
                if "Sourmash" in kreport_fname: 
                    theoretical_percent = theoretical_info[theoretical_info['Taxon'] == t]["Theoretical Distribution"].values[0]
                    this_perc = tempD.loc[kreport_df['rank'] == rk, 'proportion'].sum()
                    for thresh in detection_thresholds:
                        res ="FN"
                        perc_needed = theoretical_percent * thresh
                        #print(perc_needed)
                        if this_perc >= perc_needed and this_perc !=0:
                            res="TP"
                        detection_info.append(res)
                    #print(detection_info)
                # for all others, check if read count exceeds minimum read threshold
                else:
                    for thresh in detection_thresholds:
                        res ="FN"
                        reads_needed = theoretical_reads * thresh
                        #print(this_count, reads_needed)
                        if this_count >= reads_needed and this_count !=0:
                            res="TP"
                        #print(res)
                        detection_info.append(res)
                taxreslist = [t, rank, dataset_name, read_dataset, kreport_fname] + detection_info + [this_count]
                #print(taxreslist)
                taxres = TaxResult(*taxreslist)
                #print(taxres)
                #taxres = TaxResult(t, rank, dataset_name, read_dataset, kreport_fname, *detection_info, this_count)
                #sp_count_dict[kreport_fname].append(this_count)
                taxresults.append(taxres)
        
            # Now, look for False Positives
            fp_df= kreport_df[(~kreport_df['name'].str.contains("|".join(searchnames), regex=True))]
            rank_fp_df =  fp_df.loc[fp_df['rank'] == rk]
            for taxon in rank_fp_df['name'].to_list():
                this_taxon_count = rank_fp_df[rank_fp_df["name"] == taxon]['cumulative_count'].sum()
                taxres = TaxResult(taxon, rank, dataset_name, read_dataset, kreport_fname, "FP","FP","FP","FP", this_count)
                taxresults.append(taxres)
       
    return taxresults

                 # check if the readcounts at species level exceed the min threshold of reads
                #if temp.loc[df['rank'] == 'S', 'cumulative_count'].sum() >= detect_dict[dlevel]:
                    # if yes, add to true positive count
                #sp_tp_count += 1
                #elif temp.loc[df['rank'] == 'S', 'cumulative_count'].sum() < detect_dict[dlevel]:
                # if no, add to false negative count
                #sp_fn_count += 1
                #if this_count == 0:
                #    result_type="FN"
                    
                # for sourmash, check proportion instead?
                # if "Sourmash" in kreport_fname:
                    #
                    
                        #if "Sourmash" in kreport_fname: 
                #    this_perc =  rank_fp_df[rank_fp_df['rank'] == rk, 'proportion'].sum()
                #    for thresh in detection_thresholds:
                #        res ="FN"
                #        perc_needed = theoretical_percent * thresh
                #        #print(perc_needed)
                #        if this_perc >= perc_needed:
                ##            res="TP"
                #        detection_info.append(res)     
                # for all others, check if read count exceeds minimum read threshold
                #else:
                #    for thresh in detection_thresholds:
                #        res ="FN"
                #        reads_needed = theoretical_reads * thresh
                #        if this_count >= reads_needed:
                #            res="TP"
                #        detection_info.append(res)

# %% [markdown]
# ### Parse all kreports

# %%
#all_fp = defaultdict(dict)
all_taxres = []
for mock_community, read_datasets in all_datasets.items():
    for rd in read_datasets: 
        taxrec = assess_read_dataset(mock_community, rd, theoretical_distributions_dict, kreport_dict[rd], taxa_searchterms)
        all_taxres +=taxrec

# %% [markdown]
# ### Convert TaxResult list to DataFrame

# %%
all_results = pd.DataFrame.from_records(all_taxres, columns=TaxResult._fields)
all_results.head()
# Out:
#                         taxon     rank mock_community            read_dataset  \
# 0            Escherichia coli  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 1    Porphyromonas gingivalis  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 2      Luteovulum sphaeroides  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 3  Staphylococcus epidermidis  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 4        Streptococcus mutans  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_full
#
#            tool d1perc dp1perc dp01perc dany  cumulative_count
# 0  Sourmash-k31     TP      TP       TP   TP        4930014000
# 1  Sourmash-k31     FN      TP       TP   TP        2199344000
# 2  Sourmash-k31     TP      TP       TP   TP        5550780000
# 3  Sourmash-k31     FN      TP       TP   TP         347065000
# 4  Sourmash-k31     FN      TP       TP   TP        1845396000

# %% [markdown]
# ## Look at False Negatives

# %%
all_results[(all_results["dany"] == "FN")]
# Out:
#                           taxon     rank   mock_community  \
# 8         Staphylococcus aureus  species     ATCC_MSA1003
# 10      Acinetobacter baumannii  species     ATCC_MSA1003
# 11          Cutibacterium acnes  species     ATCC_MSA1003
# 12          Helicobacter pylori  species     ATCC_MSA1003
# 13        Lactobacillus gasseri  species     ATCC_MSA1003
# ...                         ...      ...              ...
# 48484   Clostridium perfringens  species  HiFi_Zymo_D6331
# 48486  Saccharomyces cerevisiae  species  HiFi_Zymo_D6331
# 48500                Salmonella    genus  HiFi_Zymo_D6331
# 48501              Enterococcus    genus  HiFi_Zymo_D6331
# 48502               Clostridium    genus  HiFi_Zymo_D6331
#
#                  read_dataset              tool d1perc dp1perc dp01perc dany  \
# 8      HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 10     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 11     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 12     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 13     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# ...                       ...               ...    ...     ...      ...  ...
# 48484         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48486         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48500         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48501         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48502         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
#
#        cumulative_count
# 8               1237000
# 10             52489999
# 11             39940999
# 12             14347000
# 13             10059000
# ...                 ...
# 48484                 0
# 48486                 0
# 48500                 0
# 48501                 0
# 48502                 0
#
# [517 rows x 10 columns]

# %%
fn_D6331 = all_results[(all_results["dany"] == "FN")]# & (all_results["read_dataset"] == "HiFi_Zymo_D6331")]
fn_D6331
# Out:
#                           taxon     rank   mock_community  \
# 8         Staphylococcus aureus  species     ATCC_MSA1003
# 10      Acinetobacter baumannii  species     ATCC_MSA1003
# 11          Cutibacterium acnes  species     ATCC_MSA1003
# 12          Helicobacter pylori  species     ATCC_MSA1003
# 13        Lactobacillus gasseri  species     ATCC_MSA1003
# ...                         ...      ...              ...
# 48484   Clostridium perfringens  species  HiFi_Zymo_D6331
# 48486  Saccharomyces cerevisiae  species  HiFi_Zymo_D6331
# 48500                Salmonella    genus  HiFi_Zymo_D6331
# 48501              Enterococcus    genus  HiFi_Zymo_D6331
# 48502               Clostridium    genus  HiFi_Zymo_D6331
#
#                  read_dataset              tool d1perc dp1perc dp01perc dany  \
# 8      HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 10     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 11     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 12     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# 13     HiFi_ATCC_MSA1003_full      Sourmash-k31     FN      FN       FN   FN
# ...                       ...               ...    ...     ...      ...  ...
# 48484         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48486         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48500         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48501         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
# 48502         HiFi_Zymo_D6331  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN
#
#        cumulative_count
# 8               1237000
# 10             52489999
# 11             39940999
# 12             14347000
# 13             10059000
# ...                 ...
# 48484                 0
# 48486                 0
# 48500                 0
# 48501                 0
# 48502                 0
#
# [517 rows x 10 columns]

# %%
fn_D6331['tool'].nunique()
# Out:
# 16

# %%
fn_D6331.groupby(["taxon", "rank"])['cumulative_count'].value_counts().reset_index(name = 'count')#.as_index().reindex()
# Out:
#                         taxon     rank  cumulative_count  count
# 0               Acinetobacter    genus           2059000      2
# 1               Acinetobacter    genus           6735000      2
# 2               Acinetobacter    genus          52489999      2
# 3               Acinetobacter    genus           1586000      1
# 4               Acinetobacter    genus           1601999      1
# ..                        ...      ...               ...    ...
# 245     Staphylococcus aureus  species            679000      1
# 246     Staphylococcus aureus  species            932000      1
# 247     Staphylococcus aureus  species           5636999      1
# 248  Streptococcus agalactiae  species                 0      2
# 249       Veillonella rogosae  species                 0      9
#
# [250 rows x 4 columns]

# %%
fn_sp = all_results[(all_results["dany"] == "FN") & (all_results["rank"] == "species")]
fn_gn = all_results[(all_results["dany"] == "FN") & (all_results["rank"] == "genus")]
fn_gn
# Out:
#                taxon   rank   mock_community            read_dataset  \
# 33     Acinetobacter  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 34     Cutibacterium  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 35      Helicobacter  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 36     Lactobacillus  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# 37         Neisseria  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_full
# ...              ...    ...              ...                     ...
# 46041  Saccharomyces  genus  HiFi_Zymo_D6331         HiFi_Zymo_D6331
# 47856  Saccharomyces  genus  HiFi_Zymo_D6331         HiFi_Zymo_D6331
# 48500     Salmonella  genus  HiFi_Zymo_D6331         HiFi_Zymo_D6331
# 48501   Enterococcus  genus  HiFi_Zymo_D6331         HiFi_Zymo_D6331
# 48502    Clostridium  genus  HiFi_Zymo_D6331         HiFi_Zymo_D6331
#
#                    tool d1perc dp1perc dp01perc dany  cumulative_count
# 33         Sourmash-k31     FN      FN       FN   FN          52489999
# 34         Sourmash-k31     FN      FN       FN   FN          39940999
# 35         Sourmash-k31     FN      FN       FN   FN          14347000
# 36         Sourmash-k31     FN      FN       FN   FN          10059000
# 37         Sourmash-k31     FN      FN       FN   FN          29623000
# ...                 ...    ...     ...      ...  ...               ...
# 46041   Centrifuge-h500     FN      FN       FN   FN                 0
# 47856    Centrifuge-h22     FN      FN       FN   FN                 0
# 48500  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN                 0
# 48501  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN                 0
# 48502  MEGAN-LR-Nuc-ONT     FN      FN       FN   FN                 0
#
# [225 rows x 10 columns]

# %%
fn_gn.groupby(["read_dataset", "tool"])['cumulative_count'].value_counts().reset_index(name = 'count')#.as_index().reindex()
# Out:
#                read_dataset                     tool  cumulative_count  count
# 0    HiFi_ATCC_MSA1003_full                BugSeq-V2                 0      3
# 1    HiFi_ATCC_MSA1003_full        MEGAN-LR-Nuc-HiFi                 0      5
# 2    HiFi_ATCC_MSA1003_full         MEGAN-LR-Nuc-ONT                 0      5
# 3    HiFi_ATCC_MSA1003_full            MEGAN-LR-Prot                 0      4
# 4    HiFi_ATCC_MSA1003_full               Metaphlan3                 0      3
# ..                      ...                      ...               ...    ...
# 174      ONT_R10_Zymo_D6300             Sourmash-k51          12079000      1
# 175      ONT_R10_Zymo_D6300             Sourmash-k51          14583000      1
# 176      ONT_R10_Zymo_D6300  Sourmash-k51_zeroThresh          12079000      1
# 177      ONT_R10_Zymo_D6300  Sourmash-k51_zeroThresh          14583000      1
# 178      ONT_R10_Zymo_D6300                    mOTUs                 0      2
#
# [179 rows x 4 columns]

# %%
fn_sp.groupby(["tool", "read_dataset"])['cumulative_count'].value_counts().reset_index(name = 'count')#.as_index().reindex()
# Out:
#                tool             read_dataset  cumulative_count  count
# 0           Bracken          HiFi_Zymo_D6331                 0      3
# 1         BugSeq-V2   HiFi_ATCC_MSA1003_full                 0      3
# 2         BugSeq-V2          HiFi_Zymo_D6331                 0      5
# 3    Centrifuge-h22          HiFi_Zymo_D6331                 0      4
# 4    Centrifuge-h22      Illumina_Zymo_D6300                 0      2
# ..              ...                      ...               ...    ...
# 201           mOTUs          HiFi_Zymo_D6331                 0      5
# 202           mOTUs    Illumina_ATCC_MSA1003                 0      5
# 203           mOTUs      Illumina_Zymo_D6300                 0      2
# 204           mOTUs  ONT_Q20_Zymo_D6300_full                 0      2
# 205           mOTUs       ONT_R10_Zymo_D6300                 0      2
#
# [206 rows x 4 columns]

# %%
all_results[(all_results["taxon"] == "Clostridium") & (all_results["read_dataset"] == "HiFi_Zymo_D6331")]# & (all_results["result_type"] == "FN")]
# Out:
#              taxon   rank   mock_community     read_dataset  \
# 43784  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 43821  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 43858  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44187  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44512  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44768  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44849  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44885  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45501  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45847  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45881  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45941  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 46039  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 46341  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 47854  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 48502  Clostridium  genus  HiFi_Zymo_D6331  HiFi_Zymo_D6331
#
#                           tool d1perc dp1perc dp01perc dany  cumulative_count
# 43784             Sourmash-k31     FN      FN       FN   FN                 0
# 43821             Sourmash-k51     FN      FN       FN   FN                 0
# 43858  Sourmash-k31_zeroThresh     FN      FN       FN   FN                 0
# 44187  Sourmash-k51_zeroThresh     FN      FN       FN   FN          11222999
# 44512                 Metamaps     TP      TP       TP   TP                44
# 44768                  MMseqs2     TP      TP       TP   TP               703
# 44849        MEGAN-LR-Nuc-HiFi     FN      FN       FN   FN                 0
# 44885            MEGAN-LR-Prot     TP      TP       TP   TP               381
# 45501                  Kraken2     TP      TP       TP   TP               309
# 45847                BugSeq-V2     FN      FN       FN   FN                 0
# 45881                    mOTUs     FN      FN       FN   FN                 0
# 45941               Metaphlan3     FN      FN       FN   FN                 0
# 46039          Centrifuge-h500     TP      TP       TP   TP                 2
# 46341                  Bracken     TP      TP       TP   TP               294
# 47854           Centrifuge-h22     TP      TP       TP   TP               422
# 48502         MEGAN-LR-Nuc-ONT     FN      FN       FN   FN                 0

# %%
fn_sp[(fn_sp["tool"] == "Sourmash-k31")]
# Out:
#                               taxon     rank   mock_community  \
# 8             Staphylococcus aureus  species     ATCC_MSA1003
# 10          Acinetobacter baumannii  species     ATCC_MSA1003
# 11              Cutibacterium acnes  species     ATCC_MSA1003
# 12              Helicobacter pylori  species     ATCC_MSA1003
# 13            Lactobacillus gasseri  species     ATCC_MSA1003
# 14           Neisseria meningitidis  species     ATCC_MSA1003
# 15             Phocaeicola vulgatus  species     ATCC_MSA1003
# 16     Bifidobacterium adolescentis  species     ATCC_MSA1003
# 17          Deinococcus radiodurans  species     ATCC_MSA1003
# 18            Enterococcus faecalis  species     ATCC_MSA1003
# 19            Schaalia odontolytica  species     ATCC_MSA1003
# 2162          Staphylococcus aureus  species     ATCC_MSA1003
# 2164        Acinetobacter baumannii  species     ATCC_MSA1003
# 2165            Cutibacterium acnes  species     ATCC_MSA1003
# 2166            Helicobacter pylori  species     ATCC_MSA1003
# 2167          Lactobacillus gasseri  species     ATCC_MSA1003
# 2168         Neisseria meningitidis  species     ATCC_MSA1003
# 2169           Phocaeicola vulgatus  species     ATCC_MSA1003
# 2170   Bifidobacterium adolescentis  species     ATCC_MSA1003
# 2171        Deinococcus radiodurans  species     ATCC_MSA1003
# 2172          Enterococcus faecalis  species     ATCC_MSA1003
# 2173          Schaalia odontolytica  species     ATCC_MSA1003
# 7076          Staphylococcus aureus  species     ATCC_MSA1003
# 7078        Acinetobacter baumannii  species     ATCC_MSA1003
# 7079            Cutibacterium acnes  species     ATCC_MSA1003
# 7080            Helicobacter pylori  species     ATCC_MSA1003
# 7081          Lactobacillus gasseri  species     ATCC_MSA1003
# 7082         Neisseria meningitidis  species     ATCC_MSA1003
# 7083           Phocaeicola vulgatus  species     ATCC_MSA1003
# 7084   Bifidobacterium adolescentis  species     ATCC_MSA1003
# 7085        Deinococcus radiodurans  species     ATCC_MSA1003
# 7086          Enterococcus faecalis  species     ATCC_MSA1003
# 7087          Schaalia odontolytica  species     ATCC_MSA1003
# 16183       Cryptococcus neoformans  species       Zymo_D6300
# 27859             Bacillus subtilis  species       Zymo_D6300
# 43751  Faecalibacterium prausnitzii  species  HiFi_Zymo_D6331
# 43762    Methanobrevibacter smithii  species  HiFi_Zymo_D6331
# 43763           Salmonella enterica  species  HiFi_Zymo_D6331
# 43764         Enterococcus faecalis  species  HiFi_Zymo_D6331
# 43765       Clostridium perfringens  species  HiFi_Zymo_D6331
# 43766              Candida albicans  species  HiFi_Zymo_D6331
# 43767      Saccharomyces cerevisiae  species  HiFi_Zymo_D6331
#
#                    read_dataset          tool d1perc dp1perc dp01perc dany  \
# 8        HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 10       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 11       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 12       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 13       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 14       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 15       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 16       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 17       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 18       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 19       HiFi_ATCC_MSA1003_full  Sourmash-k31     FN      FN       FN   FN
# 2162    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2164    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2165    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2166    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2167    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2168    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2169    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2170    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2171    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2172    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 2173    HiFi_ATCC_MSA1003_short  Sourmash-k31     FN      FN       FN   FN
# 7076      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7078      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7079      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7080      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7081      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7082      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7083      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7084      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7085      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7086      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 7087      Illumina_ATCC_MSA1003  Sourmash-k31     FN      FN       FN   FN
# 16183       Illumina_Zymo_D6300  Sourmash-k31     FN      FN       FN   FN
# 27859  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FN      FN       FN   FN
# 43751           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43762           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43763           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43764           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43765           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43766           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
# 43767           HiFi_Zymo_D6331  Sourmash-k31     FN      FN       FN   FN
#
#        cumulative_count
# 8               1237000
# 10             52489999
# 11             39940999
# 12             14347000
# 13             10059000
# 14             29623000
# 15             16535000
# 16               481000
# 17              4126000
# 18               273000
# 19               654000
# 2162             879000
# 2164            6735000
# 2165            5233000
# 2166            1877000
# 2167            1536000
# 2168            3933000
# 2169             715000
# 2170             113000
# 2171             609000
# 2172             227000
# 2173             155000
# 7076             684000
# 7078            2059000
# 7079            1239000
# 7080             900000
# 7081             828000
# 7082            1222000
# 7083             195000
# 7084             100000
# 7085             134000
# 7086             119999
# 7087             100000
# 16183           9523999
# 27859             98000
# 43751          69871000
# 43762          11060000
# 43763          12522000
# 43764            153000
# 43765                 0
# 43766          46414000
# 43767          38849000

# %%
all_results[(all_results["taxon"] == "Clostridium perfringens") & (all_results["read_dataset"] == "HiFi_Zymo_D6331")]#["result_type"].value_counts()#.reset_index(name = 'result_count')#.value_counts()# & (all_results["result_type"] == "FN")]
# Out:
#                          taxon     rank   mock_community     read_dataset  \
# 43765  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 43801  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 43839  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 43875  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44334  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44637  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44830  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44867  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 44902  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45830  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45864  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45898  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 45977  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 46082  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 46506  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
# 48484  Clostridium perfringens  species  HiFi_Zymo_D6331  HiFi_Zymo_D6331
#
#                           tool d1perc dp1perc dp01perc dany  cumulative_count
# 43765             Sourmash-k31     FN      FN       FN   FN                 0
# 43801             Sourmash-k51     FN      FN       FN   FN                 0
# 43839  Sourmash-k31_zeroThresh     FN      FN       FN   FN                 0
# 43875  Sourmash-k51_zeroThresh     FN      FN       FN   FN                 0
# 44334                 Metamaps     FN      FN       FN   FN                 0
# 44637                  MMseqs2     FN      FN       FN   FN                 0
# 44830        MEGAN-LR-Nuc-HiFi     FN      FN       FN   FN                 0
# 44867            MEGAN-LR-Prot     FN      FN       FN   FN                 0
# 44902                  Kraken2     TP      TP       TP   TP                 3
# 45830                BugSeq-V2     FN      FN       FN   FN                 0
# 45864                    mOTUs     FN      FN       FN   FN                 0
# 45898               Metaphlan3     FN      FN       FN   FN                 0
# 45977          Centrifuge-h500     FN      FN       FN   FN                 0
# 46082                  Bracken     FN      FN       FN   FN                 0
# 46506           Centrifuge-h22     TP      TP       TP   TP                 3
# 48484         MEGAN-LR-Nuc-ONT     FN      FN       FN   FN                 0

# %% [markdown]
# ## Look at False Positives

# %%
fp_sp = all_results[(all_results["dany"] == "FP") & (all_results["rank"] == "species")]
fp_gn = all_results[(all_results["dany"] == "FP") & (all_results["rank"] == "genus")]
fp_gn
# Out:
#                                    taxon   rank   mock_community  \
# 43                        Bradyrhizobium  genus     ATCC_MSA1003
# 44                            Paulinella  genus     ATCC_MSA1003
# 86                        Bradyrhizobium  genus     ATCC_MSA1003
# 130                       Bradyrhizobium  genus     ATCC_MSA1003
# 131                           Paulinella  genus     ATCC_MSA1003
# ...                                  ...    ...              ...
# 48466                          Mimivirus  genus  HiFi_Zymo_D6331
# 48467                    Chloriridovirus  genus  HiFi_Zymo_D6331
# 48468                      Oryzopoxvirus  genus  HiFi_Zymo_D6331
# 48469                          Pomovirus  genus  HiFi_Zymo_D6331
# 48505                          Alistipes  genus  HiFi_Zymo_D6331
#
#                  read_dataset                     tool d1perc dp1perc  \
# 43     HiFi_ATCC_MSA1003_full             Sourmash-k31     FP      FP
# 44     HiFi_ATCC_MSA1003_full             Sourmash-k31     FP      FP
# 86     HiFi_ATCC_MSA1003_full             Sourmash-k51     FP      FP
# 130    HiFi_ATCC_MSA1003_full  Sourmash-k31_zeroThresh     FP      FP
# 131    HiFi_ATCC_MSA1003_full  Sourmash-k31_zeroThresh     FP      FP
# ...                       ...                      ...    ...     ...
# 48466         HiFi_Zymo_D6331           Centrifuge-h22     FP      FP
# 48467         HiFi_Zymo_D6331           Centrifuge-h22     FP      FP
# 48468         HiFi_Zymo_D6331           Centrifuge-h22     FP      FP
# 48469         HiFi_Zymo_D6331           Centrifuge-h22     FP      FP
# 48505         HiFi_Zymo_D6331         MEGAN-LR-Nuc-ONT     FP      FP
#
#       dp01perc dany  cumulative_count
# 43          FP   FP            654000
# 44          FP   FP            654000
# 86          FP   FP            637000
# 130         FP   FP            654000
# 131         FP   FP            654000
# ...        ...  ...               ...
# 48466       FP   FP                 0
# 48467       FP   FP                 0
# 48468       FP   FP                 0
# 48469       FP   FP                 0
# 48505       FP   FP              3874
#
# [11692 rows x 10 columns]

# %%
fp_sp_counts = fp_sp.groupby(["tool", "read_dataset"])['cumulative_count'].value_counts().reset_index(name = 'count')#.as_index().reindex()
fp_sp_counts
# Out:
#                        tool             read_dataset  cumulative_count  count
# 0                   Bracken   HiFi_ATCC_MSA1003_full               142    143
# 1                   Bracken  HiFi_ATCC_MSA1003_short              1310    422
# 2                   Bracken          HiFi_Zymo_D6331              3987    242
# 3                   Bracken    Illumina_ATCC_MSA1003              1055    455
# 4                   Bracken      Illumina_Zymo_D6300             81091    439
# ..                      ...                      ...               ...    ...
# 80  Sourmash-k51_zeroThresh       ONT_R10_Zymo_D6300          12079000      3
# 81                    mOTUs   HiFi_ATCC_MSA1003_full                 0      1
# 82                    mOTUs    Illumina_ATCC_MSA1003                 0      1
# 83                    mOTUs      Illumina_Zymo_D6300                 0      2
# 84                    mOTUs  ONT_Q20_Zymo_D6300_full                 0      1
#
# [85 rows x 4 columns]

# %%
fp_sp[(fp_sp["tool"] == "Sourmash-k31")]
# Out:
#                                 taxon     rank   mock_community  \
# 20        Staphylococcus haemolyticus  species     ATCC_MSA1003
# 21        Bradyrhizobium viridifuturi  species     ATCC_MSA1003
# 22                 Bacillus pacificus  species     ATCC_MSA1003
# 23               Paulinella micropora  species     ATCC_MSA1003
# 24               Rhodobacter sp. AKP1  species     ATCC_MSA1003
# 2174      Staphylococcus haemolyticus  species     ATCC_MSA1003
# 2175            Bradyrhizobium sp. BL  species     ATCC_MSA1003
# 2176             Rhodobacter sp. AKP1  species     ATCC_MSA1003
# 7088      Staphylococcus haemolyticus  species     ATCC_MSA1003
# 7089      Coremiostelium polycephalum  species     ATCC_MSA1003
# 7090         Saccharomyces cerevisiae  species     ATCC_MSA1003
# 7091       Phyllobacterium calauticae  species     ATCC_MSA1003
# 7092                Pterula multifida  species     ATCC_MSA1003
# 7093              Phyllobacterium sp.  species     ATCC_MSA1003
# 7094             Rhodobacter sp. AKP1  species     ATCC_MSA1003
# 16184       Saccharomyces pastorianus  species       Zymo_D6300
# 16185              Bacillus sp. KbaB1  species       Zymo_D6300
# 22558       Saccharomyces pastorianus  species       Zymo_D6300
# 22559            Paulinella micropora  species       Zymo_D6300
# 22560            Bacillus inaquosorum  species       Zymo_D6300
# 22561           Bacillus intestinalis  species       Zymo_D6300
# 27862           Bacillus intestinalis  species       Zymo_D6300
# 27863       Saccharomyces pastorianus  species       Zymo_D6300
# 27864            Paulinella micropora  species       Zymo_D6300
# 27865            Bacillus inaquosorum  species       Zymo_D6300
# 27866           Escherichia sp. E4742  species       Zymo_D6300
# 27867               Bacillus sp. TSO2  species       Zymo_D6300
# 42513       Saccharomyces pastorianus  species       Zymo_D6300
# 42514            Bacillus inaquosorum  species       Zymo_D6300
# 42515            Paulinella micropora  species       Zymo_D6300
# 42516            Escherichia albertii  species       Zymo_D6300
# 42517             Bacillus sp. wens01  species       Zymo_D6300
# 42518             Bacillus sp. RHFS10  species       Zymo_D6300
# 42519            Escherichia marmotae  species       Zymo_D6300
# 42520    Stenotrophomonas maltophilia  species       Zymo_D6300
# 42521                Bacillus rugosus  species       Zymo_D6300
# 42522              Salmonella bongori  species       Zymo_D6300
# 42523             Bacillus sp. SKDU12  species       Zymo_D6300
# 43768  Faecalibacterium sp. AF28-13AC  species  HiFi_Zymo_D6331
# 43769       Saccharomyces pastorianus  species  HiFi_Zymo_D6331
#
#                    read_dataset          tool d1perc dp1perc dp01perc dany  \
# 20       HiFi_ATCC_MSA1003_full  Sourmash-k31     FP      FP       FP   FP
# 21       HiFi_ATCC_MSA1003_full  Sourmash-k31     FP      FP       FP   FP
# 22       HiFi_ATCC_MSA1003_full  Sourmash-k31     FP      FP       FP   FP
# 23       HiFi_ATCC_MSA1003_full  Sourmash-k31     FP      FP       FP   FP
# 24       HiFi_ATCC_MSA1003_full  Sourmash-k31     FP      FP       FP   FP
# 2174    HiFi_ATCC_MSA1003_short  Sourmash-k31     FP      FP       FP   FP
# 2175    HiFi_ATCC_MSA1003_short  Sourmash-k31     FP      FP       FP   FP
# 2176    HiFi_ATCC_MSA1003_short  Sourmash-k31     FP      FP       FP   FP
# 7088      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7089      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7090      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7091      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7092      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7093      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 7094      Illumina_ATCC_MSA1003  Sourmash-k31     FP      FP       FP   FP
# 16184       Illumina_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 16185       Illumina_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 22558   ONT_Q20_Zymo_D6300_full  Sourmash-k31     FP      FP       FP   FP
# 22559   ONT_Q20_Zymo_D6300_full  Sourmash-k31     FP      FP       FP   FP
# 22560   ONT_Q20_Zymo_D6300_full  Sourmash-k31     FP      FP       FP   FP
# 22561   ONT_Q20_Zymo_D6300_full  Sourmash-k31     FP      FP       FP   FP
# 27862  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 27863  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 27864  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 27865  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 27866  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 27867  ONT_Q20_Zymo_D6300_short  Sourmash-k31     FP      FP       FP   FP
# 42513        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42514        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42515        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42516        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42517        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42518        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42519        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42520        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42521        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42522        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 42523        ONT_R10_Zymo_D6300  Sourmash-k31     FP      FP       FP   FP
# 43768           HiFi_Zymo_D6331  Sourmash-k31     FP      FP       FP   FP
# 43769           HiFi_Zymo_D6331  Sourmash-k31     FP      FP       FP   FP
#
#        cumulative_count
# 20               654000
# 21               654000
# 22               654000
# 23               654000
# 24               654000
# 2174             155000
# 2175             155000
# 2176             155000
# 7088             100000
# 7089             100000
# 7090             100000
# 7091             100000
# 7092             100000
# 7093             100000
# 7094             100000
# 16184           9523999
# 16185           9523999
# 22558          74842000
# 22559          74842000
# 22560          74842000
# 22561          74842000
# 27862          47457000
# 27863          47457000
# 27864          47457000
# 27865          47457000
# 27866          47457000
# 27867          47457000
# 42513          19694000
# 42514          19694000
# 42515          19694000
# 42516          19694000
# 42517          19694000
# 42518          19694000
# 42519          19694000
# 42520          19694000
# 42521          19694000
# 42522          19694000
# 42523          19694000
# 43768          38849000
# 43769          38849000

# %%
#fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & (fp_sp['taxon'] == "Staphylococcus haemolyticus")]
#fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & (fp_sp['taxon'] == "Bradyrhizobium viridifuturi")]
#fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & (fp_sp['taxon'] == "Bacillus pacificus")]
#fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & (fp_sp['taxon'] == "Paulinella micropora")]
fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & (fp_sp['taxon'] == "Rhodobacter sp. AKP1")]
# Out:
#                      taxon     rank mock_community             read_dataset  \
# 24    Rhodobacter sp. AKP1  species   ATCC_MSA1003   HiFi_ATCC_MSA1003_full
# 111   Rhodobacter sp. AKP1  species   ATCC_MSA1003   HiFi_ATCC_MSA1003_full
# 165   Rhodobacter sp. AKP1  species   ATCC_MSA1003   HiFi_ATCC_MSA1003_full
# 2176  Rhodobacter sp. AKP1  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_short
# 2259  Rhodobacter sp. AKP1  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_short
# 2309  Rhodobacter sp. AKP1  species   ATCC_MSA1003  HiFi_ATCC_MSA1003_short
# 7094  Rhodobacter sp. AKP1  species   ATCC_MSA1003    Illumina_ATCC_MSA1003
# 7189  Rhodobacter sp. AKP1  species   ATCC_MSA1003    Illumina_ATCC_MSA1003
# 7244  Rhodobacter sp. AKP1  species   ATCC_MSA1003    Illumina_ATCC_MSA1003
#
#                          tool d1perc dp1perc dp01perc dany  cumulative_count
# 24               Sourmash-k31     FP      FP       FP   FP            654000
# 111   Sourmash-k31_zeroThresh     FP      FP       FP   FP            654000
# 165   Sourmash-k51_zeroThresh     FP      FP       FP   FP            637000
# 2176             Sourmash-k31     FP      FP       FP   FP            155000
# 2259  Sourmash-k31_zeroThresh     FP      FP       FP   FP            155000
# 2309  Sourmash-k51_zeroThresh     FP      FP       FP   FP            141000
# 7094             Sourmash-k31     FP      FP       FP   FP            100000
# 7189  Sourmash-k31_zeroThresh     FP      FP       FP   FP            100000
# 7244  Sourmash-k51_zeroThresh     FP      FP       FP   FP             77000

# %%
lr_tools

msa1003_fp = fp_sp[(fp_sp["mock_community"] == "ATCC_MSA1003") & fp_sp["tool"].isin(comparable_lr_tools)].drop(columns = ["d1perc","dp1perc", "dp01perc","dany", "rank"])#.count().reset_index()#.groupby("taxon").reset_index()
msa1003_fp
# Out:
#                                                   taxon mock_community  \
# 1212                                  Luteovulum johrii   ATCC_MSA1003
# 1213                               Rhodobacter sp. AKP1   ATCC_MSA1003
# 1214                    uncultured Rubellimicrobium sp.   ATCC_MSA1003
# 1215                      Rubellimicrobium thermophilum   ATCC_MSA1003
# 1216                     Roseinatronobacter thiooxidans   ATCC_MSA1003
# ...                                                 ...            ...
# 1290                                              Cy...   ATCC_MSA1003
# 1291                                                ...   ATCC_MSA1003
# 1292                                                ...   ATCC_MSA1003
# 1293                      Staphylococcus phage phiSa...   ATCC_MSA1003
# 1294                       Staphylococcus phage phiBU01   ATCC_MSA1003
#
#                 read_dataset     tool  cumulative_count
# 1212  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1213  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1214  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1215  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1216  HiFi_ATCC_MSA1003_full  MMseqs2                67
# ...                      ...      ...               ...
# 1290  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1291  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1292  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1293  HiFi_ATCC_MSA1003_full  MMseqs2                67
# 1294  HiFi_ATCC_MSA1003_full  MMseqs2                67
#
# [83 rows x 5 columns]

# %%
msa1003_fp.groupby(["taxon"])['tool'].count().reset_index().sort_values(by="tool", ascending=False)
# Out:
#                                                 taxon  tool
# 0                                                 ...     1
# 62                    uncultured Rubellimicrobium sp.     1
# 60                          Streptococcus troglodytae     1
# 59                           Streptococcus pneumoniae     1
# 58                              Streptococcus peroris     1
# ..                                                ...   ...
# 26                              Chlamydia trachomatis     1
# 25                                Bacillus wiedmannii     1
# 24                             Bacillus thuringiensis     1
# 23                                   Bacillus sp. M21     1
# 82                               uncultured bacterium     1
#
# [83 rows x 2 columns]

# %%
fp_gn_counts = fp_gn.groupby(["read_dataset", "tool"])['cumulative_count'].value_counts().reset_index(name = 'count')#.as_index().reindex()
fp_gn_counts
# Out:
#               read_dataset                     tool  cumulative_count  count
# 0   HiFi_ATCC_MSA1003_full                  Bracken               142     30
# 1   HiFi_ATCC_MSA1003_full           Centrifuge-h22               142     34
# 2   HiFi_ATCC_MSA1003_full          Centrifuge-h500                22     14
# 3   HiFi_ATCC_MSA1003_full                  Kraken2               142     78
# 4   HiFi_ATCC_MSA1003_full                  MMseqs2                68     42
# ..                     ...                      ...               ...    ...
# 65      ONT_R10_Zymo_D6300               Metaphlan3               617     10
# 66      ONT_R10_Zymo_D6300             Sourmash-k31          19694000      2
# 67      ONT_R10_Zymo_D6300  Sourmash-k31_zeroThresh          19694000      2
# 68      ONT_R10_Zymo_D6300             Sourmash-k51          12079000      1
# 69      ONT_R10_Zymo_D6300  Sourmash-k51_zeroThresh          12079000      1
#
# [70 rows x 4 columns]

# %%
fp_gn[(fp_gn["tool"] == "Sourmash-k51")]
# Out:
#                  taxon   rank   mock_community             read_dataset  \
# 86      Bradyrhizobium  genus     ATCC_MSA1003   HiFi_ATCC_MSA1003_full
# 2236    Bradyrhizobium  genus     ATCC_MSA1003  HiFi_ATCC_MSA1003_short
# 7160      Acytostelium  genus     ATCC_MSA1003    Illumina_ATCC_MSA1003
# 7161     Saccharomyces  genus     ATCC_MSA1003    Illumina_ATCC_MSA1003
# 7162   Phyllobacterium  genus     ATCC_MSA1003    Illumina_ATCC_MSA1003
# 22597       Paulinella  genus       Zymo_D6300  ONT_Q20_Zymo_D6300_full
# 42559    Streptococcus  genus       Zymo_D6300       ONT_R10_Zymo_D6300
# 43824    Acinetobacter  genus  HiFi_Zymo_D6331          HiFi_Zymo_D6331
#
#                tool d1perc dp1perc dp01perc dany  cumulative_count
# 86     Sourmash-k51     FP      FP       FP   FP            637000
# 2236   Sourmash-k51     FP      FP       FP   FP            141000
# 7160   Sourmash-k51     FP      FP       FP   FP             77000
# 7161   Sourmash-k51     FP      FP       FP   FP             77000
# 7162   Sourmash-k51     FP      FP       FP   FP             77000
# 22597  Sourmash-k51     FP      FP       FP   FP          61960000
# 42559  Sourmash-k51     FP      FP       FP   FP          12079000
# 43824  Sourmash-k51     FP      FP       FP   FP          38605999

# %%
fp_gn[(fp_gn["tool"] == "Sourmash-k31")]
# Out:
#                   taxon   rank mock_community              read_dataset  \
# 43       Bradyrhizobium  genus   ATCC_MSA1003    HiFi_ATCC_MSA1003_full
# 44           Paulinella  genus   ATCC_MSA1003    HiFi_ATCC_MSA1003_full
# 2195     Bradyrhizobium  genus   ATCC_MSA1003   HiFi_ATCC_MSA1003_short
# 7113     Coremiostelium  genus   ATCC_MSA1003     Illumina_ATCC_MSA1003
# 7114      Saccharomyces  genus   ATCC_MSA1003     Illumina_ATCC_MSA1003
# 7115    Phyllobacterium  genus   ATCC_MSA1003     Illumina_ATCC_MSA1003
# 7116            Pterula  genus   ATCC_MSA1003     Illumina_ATCC_MSA1003
# 22572        Paulinella  genus     Zymo_D6300   ONT_Q20_Zymo_D6300_full
# 27878        Paulinella  genus     Zymo_D6300  ONT_Q20_Zymo_D6300_short
# 42534        Paulinella  genus     Zymo_D6300        ONT_R10_Zymo_D6300
# 42535  Stenotrophomonas  genus     Zymo_D6300        ONT_R10_Zymo_D6300
#
#                tool d1perc dp1perc dp01perc dany  cumulative_count
# 43     Sourmash-k31     FP      FP       FP   FP            654000
# 44     Sourmash-k31     FP      FP       FP   FP            654000
# 2195   Sourmash-k31     FP      FP       FP   FP            155000
# 7113   Sourmash-k31     FP      FP       FP   FP            100000
# 7114   Sourmash-k31     FP      FP       FP   FP            100000
# 7115   Sourmash-k31     FP      FP       FP   FP            100000
# 7116   Sourmash-k31     FP      FP       FP   FP            100000
# 22572  Sourmash-k31     FP      FP       FP   FP          74842000
# 27878  Sourmash-k31     FP      FP       FP   FP          47457000
# 42534  Sourmash-k31     FP      FP       FP   FP          19694000
# 42535  Sourmash-k31     FP      FP       FP   FP          19694000

# %%
fp_gn_counts[fp_gn_counts["read_dataset"] == "HiFi_Zymo_D6331"]
# Out:
#        read_dataset                     tool  cumulative_count  count
# 18  HiFi_Zymo_D6331                  Bracken              3987    148
# 19  HiFi_Zymo_D6331           Centrifuge-h22                 0    613
# 20  HiFi_Zymo_D6331          Centrifuge-h500                 0     26
# 21  HiFi_Zymo_D6331                  Kraken2              3993    312
# 22  HiFi_Zymo_D6331        MEGAN-LR-Nuc-HiFi              3819      1
# 23  HiFi_Zymo_D6331         MEGAN-LR-Nuc-ONT              3874      1
# 24  HiFi_Zymo_D6331                  MMseqs2              3401     45
# 25  HiFi_Zymo_D6331                 Metamaps              3996    108
# 26  HiFi_Zymo_D6331               Metaphlan3               653     19
# 27  HiFi_Zymo_D6331             Sourmash-k51          38605999      1
# 28  HiFi_Zymo_D6331  Sourmash-k51_zeroThresh          39240999    130

# %%
fp_sp_counts[fp_sp_counts["read_dataset"] == "HiFi_Zymo_D6331"]
# Out:
#                        tool     read_dataset  cumulative_count  count
# 2                   Bracken  HiFi_Zymo_D6331              3987    242
# 12           Centrifuge-h22  HiFi_Zymo_D6331                 0   1331
# 19          Centrifuge-h500  HiFi_Zymo_D6331                 0     45
# 24                  Kraken2  HiFi_Zymo_D6331              3987    582
# 30        MEGAN-LR-Nuc-HiFi  HiFi_Zymo_D6331                 0      2
# 31         MEGAN-LR-Nuc-ONT  HiFi_Zymo_D6331                 0      1
# 32            MEGAN-LR-Prot  HiFi_Zymo_D6331              2196      1
# 34                  MMseqs2  HiFi_Zymo_D6331               810    114
# 38                 Metamaps  HiFi_Zymo_D6331              3996    161
# 43               Metaphlan3  HiFi_Zymo_D6331               636     26
# 51             Sourmash-k31  HiFi_Zymo_D6331          38849000      2
# 59  Sourmash-k31_zeroThresh  HiFi_Zymo_D6331          38849000      2
# 67             Sourmash-k51  HiFi_Zymo_D6331          38605999      3
# 75  Sourmash-k51_zeroThresh  HiFi_Zymo_D6331          39236999    295
